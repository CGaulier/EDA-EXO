# %% [markdown]
# # EDA Highschool

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('students.csv')

# %% [markdown]
# ## Prise de connaissance des données

# %%
df.head(5)
# Out:
#    Unnamed: 0 school sex  age address famsize Pstatus  Medu  Fedu     Mjob  \
# 0           0     GP   F   18       U     GT3       A     4     4  at_home
# 1           1     GP   F   17       U     GT3       T     1     1  at_home
# 2           2     GP   F   15       U     LE3       T     1     1  at_home
# 3           3     GP   F   15       U     GT3       T     4     2   health
# 4           4     GP   F   16       U     GT3       T     3     3    other
#
#   ... famrel freetime goout  Dalc  Walc  health absences  G1  G2  G3
# 0 ...      4        3     4     1     1       3        6   5   6   6
# 1 ...      5        3     3     1     1       3        4   5   5   6
# 2 ...      4        3     2     2     3       3       10   7   8  10
# 3 ...      3        2     2     1     1       5        2  15  14  15
# 4 ...      4        3     2     1     2       5        4   6  10  10
#
# [5 rows x 34 columns]

# %%
df.describe()
# Out:
#        Unnamed: 0         age        Medu        Fedu  traveltime   studytime  \
# count  395.000000  395.000000  395.000000  395.000000  337.000000  395.000000
# mean   197.000000   16.696203    2.749367    2.521519    1.445104    2.035443
# std    114.170924    1.276043    1.094735    1.088201    0.709700    0.839240
# min      0.000000   15.000000    0.000000    0.000000    1.000000    1.000000
# 25%     98.500000   16.000000    2.000000    2.000000    1.000000    1.000000
# 50%    197.000000   17.000000    3.000000    2.000000    1.000000    2.000000
# 75%    295.500000   18.000000    4.000000    3.000000    2.000000    2.000000
# max    394.000000   22.000000    4.000000    4.000000    4.000000    4.000000
#
#          failures      famrel    freetime       goout        Dalc        Walc  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean     0.334177    3.944304    3.235443    3.108861    1.481013    2.291139
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 34 columns):
# Unnamed: 0    395 non-null int64
# school        391 non-null object
# sex           395 non-null object
# age           395 non-null int64
# address       395 non-null object
# famsize       395 non-null object
# Pstatus       395 non-null object
# Medu          395 non-null int64
# Fedu          395 non-null int64
# Mjob          343 non-null object
# Fjob          345 non-null object
# reason        395 non-null object
# guardian      381 non-null object
# traveltime    337 non-null float64
# studytime     395 non-null int64
# failures      395 non-null int64
# schoolsup     395 non-null object
# famsup        395 non-null object
# paid          395 non-null object
# activities    395 non-null object
# nursery       395 non-null object
# higher        395 non-null object
# internet      395 non-null object
# romantic      395 non-null object
# ...

# %% [markdown]
# ## Gestion des données manquantes

# %%
df.isna().sum()
# Out:
# Unnamed: 0     0
# school         4
# sex            0
# age            0
# address        0
# famsize        0
# Pstatus        0
# Medu           0
# Fedu           0
# Mjob          52
# Fjob          50
# reason         0
# guardian      14
# traveltime    58
# studytime      0
# failures       0
# schoolsup      0
# famsup         0
# paid           0
# activities     0
# nursery        0
# higher         0
# internet       0
# romantic       0
# famrel         0
# freetime       0
# goout          0
# Dalc           0
# Walc           0
# health         0
# absences       0
# G1             0
# G2             0
# G3             0
# dtype: int64

# %% [markdown]
# `Seulement 58 données manquantes sur la colonne traveltime peuvent affecter les résultats`

# %% [markdown]
# ## Analyse univariée et multivariée

# %% [markdown]
# ### Analyse internet

# %% [markdown]
# #### Données impertinentes

# %%
df2 = df.absences.value_counts()
plt.subplots(figsize=(18,5))
plt.title('Comptabilisation des absences')
df2.plot.bar()

# %%
plt.title('Répartition des élèves par école')
df.school.value_counts().plot.bar()

# %% [raw]
# On remarque une grande disparité du nombre d'élève entre les deux établissements. Comparer les données par écoles n'est pas représentatif du niveau de l'école et si le choix de celle ci peut permettre d'avoir son displôme.

# %%
plt.title('Répartition des élèves par durée du trajet')
df.traveltime.value_counts().plot.bar()

# %% [raw]
# On remarque que la majorité des élèves ont un temps de trajet très court. On ne peut donc pas faire de bonnes hypothèses avec aussi peut d'élève pour l'extremum 4.

# %% [markdown]
# #### Données pertinentes

# %%
col = ['res', 'type', 'trim']

b = df.loc[:,['G1','G2','G3']]

evo = pd.DataFrame([
    [b.G1.mean(),'moyenne generale',1],
    [b.G2.mean(),'moyenne generale',2],
    [b.G3.mean(),'moyenne generale',3]],
    columns=col)
#print(evo)
plt.subplots(figsize=(18,5))
plt.title('Evolution de la moyenne générale')
sns.lineplot(x='trim',y='res',data=evo,hue="type", marker='o')

# %% [raw]
# on remarque que pour toutes les moyennes de tout les élèves au court de l'année, le deuxième trimestre est un point important car c'est a ce moment que les moyennes chuttent plus brutalement. On peut supposer un relachement des élèves au court et a la fin du 2ème trimestre. Plusieurs élements peuvent causer ce cas : la difficultés des exams, la fatigues, les vacances, etc...

# %%
plt.title('Elèves disposant d\'une connexion internet')
df.internet.value_counts().plot.bar()

# %% [raw]
# Une majorité d'élèves on accès à internet. C'est une donnée à prendre en compte surtout pour les résultats des élèves n'ayant pas internet.

# %%
plt.title('Répartition des élèves par sexe')
df.sex.value_counts().plot.bar()

# %% [raw]
# Il y a presque autant de filles que de garçons dans les écoles. Au contraire du graphe précédent, les informations sont à prendre en compte.

# %%
df.age.value_counts().plot(subplots = True, kind = 'bar')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x11a219be0>],
#       dtype=object)

# %% [raw]
# On remarque le nombres d'élèves par age : la tranche des 15-18 ans est très élevé à prendre par à l'exam. Il faut considérer le nombre des plus de 19 ans.

# %%
col = ['res', 'type', 'trim']

a1 = df[(df.sex == 'F') & (df.internet == 'no')]
b1 = a1.loc[:,['G1','G2','G3']]

a2 = df[(df.sex == 'M') & (df.internet == 'no')]
b2 = a2.loc[:,['G1','G2','G3']]

a3 = df[(df.sex == 'F') & (df.internet == 'yes')]
b3 = a3.loc[:,['G1','G2','G3']]

a4 = df[(df.sex == 'M') & (df.internet == 'yes')]
b4 = a4.loc[:,['G1','G2','G3']]

evo = pd.DataFrame([
    [b1.G1.mean(),'F no internet',1],
    [b1.G2.mean(),'F no internet',2],
    [b1.G3.mean(),'F no internet',3],
    [b2.G1.mean(),'M no internet',1],
    [b2.G2.mean(),'M no internet',2],
    [b2.G3.mean(),'M no internet',3],
    [b3.G1.mean(),'F internet',1],
    [b3.G2.mean(),'F internet',2],
    [b3.G3.mean(),'F internet',3],
    [b4.G1.mean(),'M internet',1],
    [b4.G2.mean(),'M internet',2],
    [b4.G3.mean(),'M internet',3]],
    columns=col)
#print(evo)
plt.title('Evolution de la moyenne par sexe en fonction de la connexion internet')
sns.lineplot(x='trim',y='res',data=evo,hue="type")

# %% [raw]
# On vérifie les résultats sur l'année par rapport au genre des élèves et si ils ont accès à internet. On remarque encore que le 2ème trimestre est un moment important durant la scolarité des élèves . Les hommes sans internet subisse une forte chute jusqu'à ce moment puis cette chute devient moindre. Les femmes sans internet sont elles aussi avec des résultats bas mais la chute des notes, au contraire des hommes, s'accentue. Les hommes avec internet sont les seuls a connaitre une hausse sauf pendant jusqu'au 3ème trimestre. Ils restent ceux avec la plus haute moyenne.
#
# Ce que nous pouvons supposer : les courbes tendent vers les même observations que pour les résultats généraux plus haut. On peut donc penser que le 2ème trimestre est point important durant l'année. Cependant l'influence d'internet est un vrai moteur dans la scolarité d'un élève. Internet est donc un élèment à sérieusement considéré pour réussir.

# %%
col = ['res', 'type', 'trim']

a1 = df[(df.famsize == 'GT3') ]
b1 = a1.loc[:,['G1','G2','G3']]

a2 = df[(df.famsize == 'LE3') ]
b2 = a2.loc[:,['G1','G2','G3']]

evo = pd.DataFrame([
    [b1.G1.mean(),'FamSize GT3',1],
    [b1.G2.mean(),'FamSize GT3',2],
    [b1.G3.mean(),'FamSize GT3',3],
    [b2.G1.mean(),'FamSize LT3',1],
    [b2.G2.mean(),'FamSize LT3',2],
    [b2.G3.mean(),'FamSize LT3',3]],
    columns=col)
#print(evo)
plt.subplots(figsize=(18,5))
plt.title('Evolution de la moyenne en fonction de la taille de la famille')
sns.lineplot(x='trim',y='res',data=evo,hue="type", marker='o')

# %% [raw]
# On regarde ici les moyennes tout au long de l'année par rapport au élève qui une grande ou une petite famille : Les élèves issue de familles nombreuses ont des moyennes plus basse mais pas inféreieur a 10. Les petites famille sont plus hautes. On peut supposer que les élèves ayant une grande famille ont plus de difficultés pour travailler car ils peuvent s'occuper de leur famille, avoir des difficultés pour ce concentrer.

# %%
col = ['res', 'type', 'trim']

a1 = df[(df.address == 'U') & (df.traveltime == 1)]
b1 = a1.loc[:,['G1','G2','G3']]

a2 = df[(df.address == 'U') & (df.traveltime == 2)]
b2 = a2.loc[:,['G1','G2','G3']]

a3 = df[(df.address == 'U') & (df.traveltime == 3)]
b3 = a3.loc[:,['G1','G2','G3']]

a4 = df[(df.address == 'U') & (df.traveltime == 4)]
b4 = a4.loc[:,['G1','G2','G3']]

a5 = df[(df.address == 'R') & (df.traveltime == 1)]
b5 = a5.loc[:,['G1','G2','G3']]

a6 = df[(df.address == 'R') & (df.traveltime == 2)]
b6 = a6.loc[:,['G1','G2','G3']]

a7 = df[(df.address == 'R') & (df.traveltime == 3)]
b7 = a7.loc[:,['G1','G2','G3']]

a8 = df[(df.address == 'R') & (df.traveltime == 4)]
b8 = a8.loc[:,['G1','G2','G3']]

evo = pd.DataFrame([
    [b1.G1.mean(),'ville Ttime = 1',1],
    [b1.G2.mean(),'ville Ttime = 1',2],
    [b1.G3.mean(),'ville Ttime = 1',3],
    [b2.G1.mean(),'ville Ttime = 2',1],
    [b2.G2.mean(),'ville Ttime = 2',2],
    [b2.G3.mean(),'ville Ttime = 2',3],
    [b3.G1.mean(),'ville Ttime = 3',1],
    [b3.G2.mean(),'ville Ttime = 3',2],
    [b3.G3.mean(),'ville Ttime = 3',3],
    [b4.G1.mean(),'ville Ttime = 4',1],
    [b4.G2.mean(),'ville Ttime = 4',2],
    [b4.G3.mean(),'ville Ttime = 4',3],
    [b5.G1.mean(),'campagne Ttime = 1',1],
    [b5.G2.mean(),'campagne Ttime = 1',2],
    [b5.G3.mean(),'campagne Ttime = 1',3],
    [b6.G1.mean(),'campagne Ttime = 2',1],
    [b6.G2.mean(),'campagne Ttime = 2',2],
    [b6.G3.mean(),'campagne Ttime = 2',3],
    [b7.G1.mean(),'campagne Ttime = 3',1],
    [b7.G2.mean(),'campagne Ttime = 3',2],
    [b7.G3.mean(),'campagne Ttime = 3',3],
    [b8.G1.mean(),'campagne Ttime = 4',1],
    [b8.G2.mean(),'campagne Ttime = 4',2],
    [b8.G3.mean(),'campagne Ttime = 4',3]],
    columns=col)
#print(evo)()
plt.subplots(figsize=(18,7))
plt.title('Evolution de la moyenne en fonction du trajet et du lieu de résidence')
sns.lineplot(x='trim',y='res',data=evo,hue="type", marker='o')

# %% [raw]
# On regarde ici : Les resultats des élèves par rapport à leur temps de trajet et là où ils habitent (ville ou campagne).
# On remarque que les élèves habitants à la campagne et ayant un temps de trajet long ont du mal à avoir une bonne moyenne. Etre en ville et o^avoir un temps de trajet court aide.

# %%
col2 = ['res', 'type', 'trim']

a1 = df[df.age == 15]
b1 = a1.loc[:,['G1','G2','G3']]

a2 = df[df.age == 16]
b2 = a2.loc[:,['G1','G2','G3']]

a3 = df[df.age == 17]
b3 = a3.loc[:,['G1','G2','G3']]

a4 = df[df.age == 18]
b4 = a4.loc[:,['G1','G2','G3']]

a5 = df[df.age == 19]
b5 = a5.loc[:,['G1','G2','G3']]

a6 = df[df.age == 20]
b6 = a6.loc[:,['G1','G2','G3']]

a7 = df[df.age == 21]
b7 = a7.loc[:,['G1','G2','G3']]

a8 = df[df.age == 22]
b8 = a8.loc[:,['G1','G2','G3']]

evo2 = pd.DataFrame([
    [b1.G1.mean(),'15 ans',1],
    [b1.G2.mean(),'15 ans',2],
    [b1.G3.mean(),'15 ans',3],
    [b2.G1.mean(),'16 ans',1],
    [b2.G2.mean(),'16 ans',2],
    [b2.G3.mean(),'16 ans',3],
    [b3.G1.mean(),'17 ans',1],
    [b3.G2.mean(),'17 ans',2],
    [b3.G3.mean(),'17 ans',3],
    [b4.G1.mean(),'18 ans',1],
    [b4.G2.mean(),'18 ans',2],
    [b4.G3.mean(),'18 ans',3],
    [b5.G1.mean(),'19 ans',1],
    [b5.G2.mean(),'19 ans',2],
    [b5.G3.mean(),'19 ans',3],
    [b6.G1.mean(),'20 ans',1],
    [b6.G2.mean(),'20 ans',2],
    [b6.G3.mean(),'20 ans',3],
    [b7.G1.mean(),'21 ans',1],
    [b7.G2.mean(),'21 ans',2],
    [b7.G3.mean(),'21 ans',3],
    [b8.G1.mean(),'22 ans',1],
    [b8.G2.mean(),'22 ans',2],
    [b8.G3.mean(),'22 ans',3]],
    columns=col2)
#print(evo)
plt.subplots(figsize=(18,8))
plt.title('Evolution de la moyenne en fonction de l\'âge')
sns.lineplot(x='trim',y='res',data=evo2,hue="type",marker='o')

# %% [raw]
# On regarde les resultats au long de l'année par rapport à l'age. Pour rappelle les résultats interessant sont pour les 15-18 ans . Ils tiennent tous au dessus de la moyenne mais les 15 ans sont ceux qui ont les meilleurs résultats . On appréciera les résultats des 20 ans.

# %%
df.internet[df['internet']=='yes'] = 1
df.internet[df['internet']=='no'] = 0

plt.title('Accès à internet par sexe')
sns.barplot(x ='sex',y ='internet',data=df)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# ...

# %% [raw]
# On regarde qui entre les femmes et les hommes ont plus ou non accès à internet. C'est presque équivalent.

# %%
dfo = df.groupby('G1').schoolsup.value_counts().sort_index().unstack()
dfo.plot.bar(stacked=True)

dfo2 = df.groupby('G2').schoolsup.value_counts().sort_index().unstack()
plt.title('Moyenne sur les trois trimestres en fonction des cours particuliers')
dfo2.plot.bar(stacked=True)

dfo3 = df.groupby('G3').schoolsup.value_counts().sort_index().unstack()
dfo3.plot.bar(stacked=True)

# %% [raw]
# On regarde la note des élèves qui ont du soutient scolaire : Finalement, l'aide scolaire n'est pas très utile.

# %%
plt.title('Répartition des élèves en fonction du temps d\'études')
df.studytime.value_counts().plot.bar()

# %% [raw]
# On observe le nombre d'élève réparti par leur temps d'étude.

# %%
col = ['res', 'type', 'trim']

a1 = df[(df.studytime == 1)]
b1 = a1.loc[:,['G1','G2','G3']]

a2 = df[(df.studytime == 2)]
b2 = a2.loc[:,['G1','G2','G3']]

a3 = df[(df.studytime == 3)]
b3 = a3.loc[:,['G1','G2','G3']]

a4 = df[(df.studytime == 4)]
b4 = a4.loc[:,['G1','G2','G3']]

evo = pd.DataFrame([
    [b1.G1.mean(),'studyTime = 1',1],
    [b1.G2.mean(),'studyTime = 1',2],
    [b1.G3.mean(),'studyTime = 1',3],
    [b2.G1.mean(),'studyTime = 2',1],
    [b2.G2.mean(),'studyTime = 2',2],
    [b2.G3.mean(),'studyTime = 2',3],
    [b3.G1.mean(),'studyTime = 3',1],
    [b3.G2.mean(),'studyTime = 3',2],
    [b3.G3.mean(),'studyTime = 3',3],
    [b4.G1.mean(),'studyTime = 4',1],
    [b4.G2.mean(),'studyTime = 4',2],
    [b4.G3.mean(),'studyTime = 4',3]],
    columns=col)
#print(evo)
plt.subplots(figsize=(18,5))
plt.title('Evolution de la moyenne en fonction du temps d\'études')
sns.lineplot(x='trim',y='res',data=evo,hue="type", marker='o')

# %% [raw]
# On observe ici : les résultats sur l'année par rapport eu temps d'étude : on remarque que les moyennes sont toute au dessus de 10 mais sur le 1 et 2 qui ont plus d'élève on observe une baisse au deuxième trimestre.

# %%
col = ['res', 'type', 'trim']

a1 = df[(df.Medu == 1)]
b1 = a1.loc[:,['G1','G2','G3']]

a2 = df[(df.Medu == 2)]
b2 = a2.loc[:,['G1','G2','G3']]

a3 = df[(df.Medu == 3)]
b3 = a3.loc[:,['G1','G2','G3']]

a4 = df[(df.Medu == 4)]
b4 = a4.loc[:,['G1','G2','G3']]

evo = pd.DataFrame([
    [b1.G1.mean(),'medu = 1',1],
    [b1.G2.mean(),'medu = 1',2],
    [b1.G3.mean(),'medu = 1',3],
    [b2.G1.mean(),'medu = 2',1],
    [b2.G2.mean(),'medu = 2',2],
    [b2.G3.mean(),'medu = 2',3],
    [b3.G1.mean(),'medu = 3',1],
    [b3.G2.mean(),'medu = 3',2],
    [b3.G3.mean(),'medu = 3',3],
    [b4.G1.mean(),'medu = 4',1],
    [b4.G2.mean(),'medu = 4',2],
    [b4.G3.mean(),'medu = 4',3]],
    columns=col)
#print(evo)
plt.subplots(figsize=(18,5))
sns.lineplot(x='trim',y='res',data=evo,hue="type", marker='o')

col = ['res', 'type', 'trim']

a1 = df[(df.Fedu == 1)]
b1 = a1.loc[:,['G1','G2','G3']]

a2 = df[(df.Fedu == 2)]
b2 = a2.loc[:,['G1','G2','G3']]

a3 = df[(df.Fedu == 3)]
b3 = a3.loc[:,['G1','G2','G3']]

a4 = df[(df.Fedu == 4)]
b4 = a4.loc[:,['G1','G2','G3']]

evo = pd.DataFrame([
    [b1.G1.mean(),'fedu = 1',1],
    [b1.G2.mean(),'fedu = 1',2],
    [b1.G3.mean(),'fedu = 1',3],
    [b2.G1.mean(),'fedu = 2',1],
    [b2.G2.mean(),'fedu = 2',2],
    [b2.G3.mean(),'fedu = 2',3],
    [b3.G1.mean(),'fedu = 3',1],
    [b3.G2.mean(),'fedu = 3',2],
    [b3.G3.mean(),'fedu = 3',3],
    [b4.G1.mean(),'fedu = 4',1],
    [b4.G2.mean(),'fedu = 4',2],
    [b4.G3.mean(),'fedu = 4',3]],
    columns=col)
#print(evo)
plt.title('Evolution des notes en fonction de l\'éducation de des parents')
plt.subplots(figsize=(18,5))
sns.lineplot(x='trim',y='res',data=evo,hue="type", marker='o')

# %% [raw]
# On regarde lesnotes des élèves par rapport a l'éducation des parents . Et une éducation haute est préférable sans doute pour l'aide aux devoirs et pour les methodes de travail ?

# %%
plt.subplots(figsize=(10,9))
sns.heatmap(df.corr())
plt.title('Corrélation entre les variables')
sns.heatmap(df.corr(),vmin=0,vmax=0.2)

# %% [raw]
# Vision d'ensemble

# %% [markdown]
# # CONCLUSION
